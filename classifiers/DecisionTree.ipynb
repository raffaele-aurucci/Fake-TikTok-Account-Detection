# %% [markdown]
# # Addestramento DecisionTree

# %% [markdown]
# > Import necessari

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV, learning_curve
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# > Montaggio di Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Divisione del dataset in train e test

# %%
# Lettura del dataset (drive)
csv_path = '/content/drive/MyDrive/Progetto_FDSML_github/FakeAccountDetection/datasets/cleaned_dataset.csv'

# %%
df = pd.read_csv(csv_path)

# %%
# Divisione in train e test set
X = df.copy()
y = X.pop('fake')

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in sss.split(X, y):
    X_train, X_test = X.loc[train_index], X.loc[test_index]
    y_train, y_test = y.loc[train_index], y.loc[test_index]

# %% [markdown]
# ### 1.1 Addestramento senza iperparametri

# %%
# Istanziazione e addestramento del classificatore
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)

# Stampa delle metriche
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Precision: {precision_score(y_test, y_pred)}')
print(f'Recall: {recall_score(y_test, y_pred)}')
print(f'F1-Score: {f1_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.9975111996017919
# Precision: 0.9960356788899901
# Recall: 0.9990059642147118
# F1-Score: 0.9975186104218362

# %% [markdown]
# ## 2. Grid Search Cross Validation

# %%
# Griglia dei parametri corretta
param_grid = {
    'criterion': ['gini'],
    'max_depth': [10, 15, 20],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3],
    'max_features': [None, 3, 7],
    'max_leaf_nodes': [5, 10, 15]
}

# %%
# Istanziazione del classificatore (random_state garantisce che ad ogni esecuzione vi siano sempre gli stessi iperparametri migliori)
dt = DecisionTreeClassifier(random_state=42)

# %%
# %%time
# Stampiamo i migliori parametri
grid_search = GridSearchCV(estimator=dt, param_grid=param_grid, cv=10, scoring='accuracy', n_jobs=-1, return_train_score=True, error_score='raise')
grid_search.fit(X_train, y_train)
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 2}
# CPU times: user 3.04 s, sys: 676 ms, total: 3.72 s
# Wall time: 48.7 s

# %%
# Vediamo come si comporta nelle diverse combinazioni di parametri
cvres = grid_search.cv_results_

for i, (accuracy, params) in enumerate(zip(cvres["mean_test_score"], cvres["params"])):
    print(f"Iterazione {i}: Accuracy {accuracy}, Parametri {params}")
# Out:
# Iterazione 0: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Iterazione 1: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3}
# Iterazione 2: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 4}
# Iterazione 3: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Iterazione 4: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3}
# Iterazione 5: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Iterazione 6: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Iterazione 7: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Iterazione 8: Accuracy 0.993278005985019, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 4}
# Iterazione 9: Accuracy 0.9957675817673772, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Iterazione 10: Accuracy 0.9957675817673772, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 3}
# Iterazione 11: Accuracy 0.9957675817673772, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 4}
# Iterazione 12: Accuracy 0.9958921147686226, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Iterazione 13: Accuracy 0.9958921147686226, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 3}
# Iterazione 14: Accuracy 0.9958921147686226, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Iterazione 15: Accuracy 0.9957675817673772, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Iterazione 16: Accuracy 0.9957675817673772, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Iterazione 17: Accuracy 0.9957675817673772, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 3, 'min_samples_split': 4}
# Iterazione 18: Accuracy 0.9965140053158862, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Iterazione 19: Accuracy 0.9967630713183769, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'min_samples_split': 3}
# Iterazione 20: Accuracy 0.9967630713183769, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'min_samples_split': 4}
# Iterazione 21: Accuracy 0.9962650942051884, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Iterazione 22: Accuracy 0.9962650942051884, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 3}
# Iterazione 23: Accuracy 0.9962650942051884, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Iterazione 24: Accuracy 0.9967632262101696, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Iterazione 25: Accuracy 0.9967632262101696, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Iterazione 26: Accuracy 0.9967632262101696, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 4}
# Iterazione 27: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Iterazione 28: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3}
# Iterazione 29: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 4}
# Iterazione 30: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Iterazione 31: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3}
# Iterazione 32: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Iterazione 33: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Iterazione 34: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Iterazione 35: Accuracy 0.92631022967355, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 4}
# Iterazione 36: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Iterazione 37: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 3}
# Iterazione 38: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 4}
# Iterazione 39: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Iterazione 40: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 3}
# Iterazione 41: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Iterazione 42: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Iterazione 43: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Iterazione 44: Accuracy 0.9790883688655105, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 3, 'min_samples_split': 4}
# Iterazione 45: Accuracy 0.9851872331988872, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Iterazione 46: Accuracy 0.9851872331988872, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'min_samples_split': 3}
# Iterazione 47: Accuracy 0.9851872331988872, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'min_samples_split': 4}
# Iterazione 48: Accuracy 0.9851872331988872, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Iterazione 49: Accuracy 0.9851872331988872, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 3}
# Iterazione 50: Accuracy 0.9851872331988872, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Iterazione 51: Accuracy 0.9849384769799819, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Iterazione 52: Accuracy 0.9849384769799819, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Iterazione 53: Accuracy 0.9849384769799819, Parametri {'criterion': 'gini', 'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 4}
# Iterazione
Accuracy 0.9932780059850188, Parametri {'criterion': 'gini', 'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'min_samples_split': 4}
# Iterazione 237: Accuracy 0.9932780059850188, Parametri {'criterion': 'gini', 'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Iterazione 238: Accuracy 0.9932780059850188, Parametri {'criterion': 'gini', 'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 3}
# Iterazione 239: Accuracy 0.9932780059850188, Parametri {'criterion': 'gini', 'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Iterazione 240: Accuracy 0.9927800288718303, Parametri {'criterion': 'gini', 'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Iterazione 241: Accuracy 0.9927800288718303, Parametri {'criterion': 'gini', 'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Iterazione 242: Accuracy 0.9927800288718303, Parametri {'criterion': 'gini', 'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'min_samples_split': 4}

# %% [markdown]
# ## 4. Metriche del modello migliore

# %% [markdown]
# > Vengono misurate le metriche a seguito dell'Hyperparameter Tuning.

# %%
dt_final = grid_search.best_estimator_
y_pred = dt_final.predict(X_test)

# Stampa delle metriche
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Precision: {precision_score(y_test, y_pred)}')
print(f'Recall: {recall_score(y_test, y_pred)}')
print(f'F1-Score: {f1_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.9975111996017919
# Precision: 0.9960356788899901
# Recall: 0.9990059642147118
# F1-Score: 0.9975186104218362

# %% [markdown]
# ### 4.1 Learning Curve

# %%
# Istanzia un nuovo modello KNN con i migliori parametri ottenuti in precedenza
dt = DecisionTreeClassifier(**grid_search.best_params_)

# Calcolo la learning curve
train_sizes, train_scores, test_scores = learning_curve(dt, X_train, y_train, scoring='accuracy',
                                                        train_sizes=np.linspace(0.1, 1.0, 10), n_jobs=-1, cv=10)

# Calcola la media dei punteggi ottenuti nelle diverse iterazioni di cross validation
train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)

# Traccio la curva di apprendimento
plt.figure()
plt.title("Learning Curve (KNN)")
plt.xlabel("Training examples")
plt.ylabel("Accuracy")
plt.grid()

plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training accuracy")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Validation accuracy")

plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### 4.2 Matrice di confusione

# %%
cm = confusion_matrix(y_test, y_pred)
class_names = ['Real', 'Fake']

plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_names, yticklabels=class_names)

plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# Salva il grafico come file PDF
plt.savefig('confusion_matrix_DT.pdf', format='pdf')

# %% [markdown]
# ### 4.3 Roc Curve

# %%
y_proba = dt_final.predict_proba(X_test)

# Calcolo della curva ROC per la classe 'real' (label 0)
fpr_real, tpr_real, _ = roc_curve(y_test, y_proba[:, 0], pos_label=0)
roc_auc_real = auc(fpr_real, tpr_real)

# Calcolo della curva ROC per la classe 'fake' (label 1)
fpr_fake, tpr_fake, _ = roc_curve(y_test, y_proba[:, 1], pos_label=1)
roc_auc_fake = auc(fpr_fake, tpr_fake)

# Tracciamento delle curve ROC
plt.figure(figsize=(6, 5))
plt.plot(fpr_real, tpr_real, color='darkorange', lw=2, label=f'ROC curve real (AUC = {roc_auc_real:.2f})')
plt.plot(fpr_fake, tpr_fake, color='blue', lw=2, label=f'ROC curve fake (AUC = {roc_auc_fake:.2f})')
plt.plot([0, 1], [0, 1], color='black', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(False)
plt.legend(loc='lower right')
plt.title('ROC Curve')
plt.show()
